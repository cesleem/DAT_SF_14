# %%
# !pwd
# Out:
# /Users/ceslee-work/w/generalassembly/DAT_SF_14/labs

# %%
import pandas as pd

df = pd.read_csv('/Users/ceslee-work/Downloads/Pearson.csv')

# %%
df.head()
# Out:
#    Father   Son
# 0    65.0  59.8
# 1    63.3  63.2
# 2    65.0  63.3
# 3    65.8  62.8
# 4    61.1  64.3

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
fig = plt.figure(figsize=(20,16))

ax = fig.add_subplot(1,2,1)
plt.hist(df.Father)

ax = fig.add_subplot(1,2,2)
plt.hist(df.Son)
# Out:
# (array([   5.,   14.,   52.,  141.,  297.,  297.,  176.,   76.,   14.,    6.]),
#  array([ 58.5 ,  60.49,  62.48,  64.47,  66.46,  68.45,  70.44,  72.43,
#          74.42,  76.41,  78.4 ]),
#  <a list of 10 Patch objects>)
